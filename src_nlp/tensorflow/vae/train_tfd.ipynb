# %% [markdown]
# Notebook written by [Zhedong Zheng](https://github.com/zhedongzheng)
#
# ![alt text](vae.png)

# %%
import tensorflow as tf
import numpy as np

# %%
PARAMS = {
    'max_len': 15,
    'vocab_size': 10000,
    'embed_dims': 128,
    'rnn_size': 128,
    'latent_size': 16,
    'beam_width': 5,
    'num_sampled': 1000,
    'clip_norm': 5.0,
    'anneal_max': 1.0,
    'anneal_bias': 6000,
    'batch_size': 128,
    'n_epochs': 10,
}

# %%
def build_vocab(index_from=4):
    PARAMS['word2idx'] = tf.keras.datasets.imdb.get_word_index()
    PARAMS['word2idx'] = {k: (v + index_from) for k, v in PARAMS['word2idx'].items()}
    PARAMS['word2idx']['<pad>'] = 0
    PARAMS['word2idx']['<start>'] = 1
    PARAMS['word2idx']['<unk>'] = 2
    PARAMS['word2idx']['<end>'] = 3
    PARAMS['idx2word'] = {i: w for w, i in PARAMS['word2idx'].items()}

    
def load_data(index_from=4):
    (X_train, _), (X_test, _) = tf.contrib.keras.datasets.imdb.load_data(
        num_words=PARAMS['vocab_size'], index_from=index_from)
    return (X_train, X_test)

# %%
word2idx = build_vocab()
X = np.concatenate(load_data())

X = np.concatenate((
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='post', padding='post'),
    tf.keras.preprocessing.sequence.pad_sequences(
        X, PARAMS['max_len'], truncating='pre', padding='post')))

enc_inp = X[:, 1:]
dec_inp = X
dec_out = np.concatenate([X[:, 1:], np.full([X.shape[0], 1], PARAMS['word2idx']['<end>'])], 1)

# %%
def kl_w_fn(global_step):
    return PARAMS['anneal_max'] * tf.sigmoid((10 / PARAMS['anneal_bias']) * (
        tf.to_float(global_step) - tf.constant(PARAMS['anneal_bias'] / 2)))

def clip_grads(loss):
    variables = tf.trainable_variables()
    grads = tf.gradients(loss, variables)
    clipped_grads, _ = tf.clip_by_global_norm(grads, PARAMS['clip_norm'])
    return zip(clipped_grads, variables)

def rnn_cell():
    return tf.nn.rnn_cell.GRUCell(PARAMS['rnn_size'],
                                  kernel_initializer=tf.orthogonal_initializer())

# %%
def forward(inputs, labels, mode):
    is_training = (mode == tf.estimator.ModeKeys.TRAIN)
    enc_seq_len = tf.count_nonzero(inputs, 1, dtype=tf.int32)
    batch_sz = tf.shape(inputs)[0]
    
    with tf.variable_scope('Encoder'):
        embedding = tf.get_variable('lookup_table', [PARAMS['vocab_size'], PARAMS['embed_dims']])
        x = tf.nn.embedding_lookup(embedding, inputs)
        
        _, enc_state = tf.nn.dynamic_rnn(rnn_cell(), x, enc_seq_len, dtype=tf.float32)
        
        z_mean = tf.layers.dense(enc_state, PARAMS['latent_size'])
        z_var = tf.layers.dense(enc_state, PARAMS['latent_size'])
        
    posterior = tf.contrib.distributions.MultivariateNormalDiag(z_mean, z_var)
    prior = tf.contrib.distributions.MultivariateNormalDiag(tf.zeros_like(z_mean),
                                                            tf.ones_like(z_var))
        
    with tf.variable_scope('Decoder'):
        init_state = tf.layers.dense(posterior.sample(), PARAMS['rnn_size'], tf.nn.elu)
        output_proj = tf.layers.Dense(PARAMS['vocab_size'])
        dec_cell = rnn_cell()
        
        if is_training:
            dec_seq_len = tf.count_nonzero(labels['dec_out'], 1, dtype=tf.int32)
            
            helper = tf.contrib.seq2seq.TrainingHelper(
                inputs = tf.nn.embedding_lookup(embedding, labels['dec_inp']),
                sequence_length = dec_seq_len)
            decoder = tf.contrib.seq2seq.BasicDecoder(
                cell = dec_cell,
                helper = helper,
                initial_state = init_state,
                output_layer = output_proj)
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder,
                maximum_iterations = tf.reduce_max(dec_seq_len))
            logits = decoder_output.rnn_output
            
            return logits, posterior, prior
        else:
            decoder = tf.contrib.seq2seq.BeamSearchDecoder(
                cell = dec_cell,
                embedding = embedding,
                start_tokens = tf.tile(tf.constant([PARAMS['word2idx']['<start>']], tf.int32),
                                       [batch_sz]),
                end_token = PARAMS['word2idx']['<end>'],
                initial_state = tf.contrib.seq2seq.tile_batch(init_state, PARAMS['beam_width']),
                beam_width = PARAMS['beam_width'],
                output_layer = output_proj)
            decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(
                decoder = decoder)
            
            return decoder_output.predicted_ids[:, :, 0]

# %%
def model_fn(features, labels, mode):
    logits_or_ids = forward(features, labels, mode)        
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        return tf.estimator.EstimatorSpec(mode, predictions=logits_or_ids)
        
    if mode == tf.estimator.ModeKeys.TRAIN:
        logits, posterior, prior = logits_or_ids
        
        out_dist = tf.distributions.Categorical(logits)
        
        global_step = tf.train.get_global_step()
        
        nll_loss = - tf.reduce_sum(out_dist.log_prob(labels['dec_out']))
        
        kl_w = kl_w_fn(global_step)
        
        kl_loss = tf.reduce_sum(tf.distributions.kl_divergence(posterior, prior))
        
        loss_op = nll_loss + kl_w * kl_loss
        
        train_op = tf.train.AdamOptimizer().apply_gradients(clip_grads(loss_op),
                                                            global_step = global_step)
        
        lth = tf.train.LoggingTensorHook(
            {'nll_loss': nll_loss, 'kl_w': kl_w, 'kl_loss': kl_loss}, every_n_iter=100)
        
        return tf.estimator.EstimatorSpec(
            mode=mode, loss=loss_op, train_op=train_op, training_hooks=[lth])

# %%
def inf_inp(test_strs):
    x = [[PARAMS['word2idx'].get(w, 2) for w in s.split()] for s in test_strs]
    x = tf.keras.preprocessing.sequence.pad_sequences(
        x, PARAMS['max_len'], truncating='post', padding='post')
    return x

def demo(test_strs, pred_ids):
    for s, pred in zip(test_strs, pred_ids):
        print('\nOriginal:', s)
        print('Reconstr:', ' '.join([PARAMS['idx2word'].get(idx, '<unk>') for idx in pred]))


test_strs = ['i love this film and i think it is one of the best films',
             'this movie is a waste of time and there is no point to watch it']

estimator = tf.estimator.Estimator(model_fn)

for _ in range(PARAMS['n_epochs']):
    estimator.train(tf.estimator.inputs.numpy_input_fn(
        x = enc_inp,
        y = {'dec_inp': dec_inp, 'dec_out': dec_out},
        batch_size = PARAMS['batch_size'],
        shuffle = True))

    pred_ids = list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
        x = inf_inp(test_strs),
        shuffle = False)))

    demo(test_strs, pred_ids)
    print()
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x114d6f668>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:loss = 17755.77, step = 1
# INFO:tensorflow:nll_loss = 17683.855, kl_w = 0.006692851, kl_loss = 10744.9
# INFO:tensorflow:global_step/sec: 1.47573
# INFO:tensorflow:loss = 12152.365, step = 101 (67.764 sec)
# INFO:tensorflow:nll_loss = 12131.943, kl_w = 0.007897083, kl_loss = 2585.9463 (67.764 sec)
# INFO:tensorflow:global_step/sec: 1.46193
# INFO:tensorflow:loss = 11394.983, step = 201 (68.403 sec)
# INFO:tensorflow:nll_loss = 11343.993, kl_w = 0.009315956, kl_loss = 5473.3965 (68.403 sec)
# INFO:tensorflow:global_step/sec: 1.35898
# INFO:tensorflow:loss = 11459.998, step = 301 (73.585 sec)
# INFO:tensorflow:nll_loss = 11402.32, kl_w = 0.010986943, kl_loss = 5249.655 (73.586 sec)
# INFO:tensorflow:global_step/sec: 1.38963
# INFO:tensorflow:loss = 10782.0205, step = 401 (71.961 sec)
# INFO:tensorflow:nll_loss = 10726.691, kl_w = 0.012953726, kl_loss = 4271.2744 (71.961 sec)
# INFO:tensorflow:global_step/sec: 1.29742
# INFO:tensorflow:loss = 10658.796, step = 501 (77.076 sec)
# INFO:tensorflow:nll_loss = 10601.286, kl_w = 0.015267149, kl_loss = 3766.8833 (77.076 sec)
# INFO:tensorflow:global_step/sec: 1.30094
# INFO:tensorflow:loss = 10857.655, step = 601 (76.868 sec)
# INFO:tensorflow:nll_loss = 10814.296, kl_w = 0.01798621, kl_loss = 2410.692 (76.868 sec)
# INFO:tensorflow:global_step/sec: 1.38517
# INFO:tensorflow:loss = 10773.176, step = 701 (72.193 sec)
# INFO:tensorflow:nll_loss = 10722.124, kl_w = 0.021179108, kl_loss = 2410.4854 (72.193 sec)
# INFO:tensorflow:Saving checkpoints for 782 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:Loss for final step: 2689.7695.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: this movie is the movie of this movie is a movie of it movie <end> <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is the movie of the movie of the movie of the movie <end> <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-782
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 783 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:loss = 10558.87, step = 783
# INFO:tensorflow:nll_loss = 10496.998, kl_w = 0.024205629, kl_loss = 2556.098
# INFO:tensorflow:global_step/sec: 1.39204
# INFO:tensorflow:loss = 9698.51, step = 883 (71.838 sec)
# INFO:tensorflow:nll_loss = 9619.435, kl_w = 0.028470589, kl_loss = 2777.4248 (71.838 sec)
# INFO:tensorflow:global_step/sec: 1.35906
# INFO:tensorflow:loss = 10057.557, step = 983 (73.581 sec)
# INFO:tensorflow:nll_loss = 9982.916, kl_w = 0.033461247, kl_loss = 2230.672 (73.581 sec)
# INFO:tensorflow:global_step/sec: 1.31423
# INFO:tensorflow:loss = 9933.79, step = 1083 (76.090 sec)
# INFO:tensorflow:nll_loss = 9837.971, kl_w = 0.039291352, kl_loss = 2438.6763 (76.090 sec)
# INFO:tensorflow:global_step/sec: 1.39535
# INFO:tensorflow:loss = 9707.539, step = 1183 (71.667 sec)
# INFO:tensorflow:nll_loss = 9591.219, kl_w = 0.04608883, kl_loss = 2523.8313 (71.667 sec)
# INFO:tensorflow:global_step/sec: 1.2258
# INFO:tensorflow:loss = 9753.191, step = 1283 (81.579 sec)
# INFO:tensorflow:nll_loss = 9620.42, kl_w = 0.053996176, kl_loss = 2458.9053 (81.579 sec)
# INFO:tensorflow:global_step/sec: 1.3064
# INFO:tensorflow:loss = 9375.065, step = 1383 (76.546 sec)
# INFO:tensorflow:nll_loss = 9214.898, kl_w = 0.06317033, kl_loss = 2535.4783 (76.546 sec)
# INFO:tensorflow:global_step/sec: 1.29805
# INFO:tensorflow:loss = 9138.991, step = 1483 (77.038 sec)
# INFO:tensorflow:nll_loss = 8949.715, kl_w = 0.07378165, kl_loss = 2565.357 (77.038 sec)
# INFO:tensorflow:Saving checkpoints for 1564 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:Loss for final step: 2125.4438.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i saw this movie i saw this film i have ever seen the <end> <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is one of this movie if you want to see this movie <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-1564
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1565 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:loss = 8910.833, step = 1565
# INFO:tensorflow:nll_loss = 8703.543, kl_w = 0.08368247, kl_loss = 2477.1064
# INFO:tensorflow:global_step/sec: 1.42313
# INFO:tensorflow:loss = 8740.83, step = 1665 (70.269 sec)
# INFO:tensorflow:nll_loss = 8504.821, kl_w = 0.09738124, kl_loss = 2423.558 (70.269 sec)
# INFO:tensorflow:global_step/sec: 1.28377
# INFO:tensorflow:loss = 9195.483, step = 1765 (77.895 sec)
# INFO:tensorflow:nll_loss = 8921.405, kl_w = 0.11304584, kl_loss = 2424.4902 (77.895 sec)
# INFO:tensorflow:global_step/sec: 1.29572
# INFO:tensorflow:loss = 9040.881, step = 1865 (77.177 sec)
# INFO:tensorflow:nll_loss = 8746.483, kl_w = 0.13086486, kl_loss = 2249.6306 (77.177 sec)
# INFO:tensorflow:global_step/sec: 1.24058
# INFO:tensorflow:loss = 9059.817, step = 1965 (80.608 sec)
# INFO:tensorflow:nll_loss = 8716.196, kl_w = 0.15101443, kl_loss = 2275.418 (80.608 sec)
# INFO:tensorflow:global_step/sec: 1.31367
# INFO:tensorflow:loss = 9069.443, step = 2065 (76.122 sec)
# INFO:tensorflow:nll_loss = 8711.575, kl_w = 0.17364664, kl_loss = 2060.9014 (76.122 sec)
# INFO:tensorflow:global_step/sec: 1.36133
# INFO:tensorflow:loss = 8582.193, step = 2165 (73.458 sec)
# INFO:tensorflow:nll_loss = 8167.4224, kl_w = 0.19887616, kl_loss = 2085.5718 (73.458 sec)
# INFO:tensorflow:global_step/sec: 1.20315
# INFO:tensorflow:loss = 8836.953, step = 2265 (83.115 sec)
# INFO:tensorflow:nll_loss = 8403.338, kl_w = 0.22676536, kl_loss = 1912.1763 (83.115 sec)
# INFO:tensorflow:Saving checkpoints for 2339 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 2346 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:Loss for final step: 2198.5479.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-2346
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i saw this film and i saw this film and the first of the <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a good fan of time and i watched it to watch <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-2346
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 2347 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:loss = 8602.737, step = 2347
# INFO:tensorflow:nll_loss = 8131.086, kl_w = 0.25161827, kl_loss = 1874.4733
# INFO:tensorflow:global_step/sec: 1.29019
# INFO:tensorflow:loss = 8674.076, step = 2447 (77.509 sec)
# INFO:tensorflow:nll_loss = 8196.737, kl_w = 0.2842792, kl_loss = 1679.1211 (77.509 sec)
# INFO:tensorflow:global_step/sec: 1.36195
# INFO:tensorflow:loss = 8933.747, step = 2547 (73.424 sec)
# INFO:tensorflow:nll_loss = 8413.503, kl_w = 0.31937042, kl_loss = 1628.969 (73.424 sec)
# INFO:tensorflow:global_step/sec: 1.33174
# INFO:tensorflow:loss = 9125.028, step = 2647 (75.090 sec)
# INFO:tensorflow:nll_loss = 8565.346, kl_w = 0.35663486, kl_loss = 1569.3428 (75.090 sec)
# INFO:tensorflow:global_step/sec: 1.3577
# INFO:tensorflow:loss = 9088.255, step = 2747 (73.654 sec)
# INFO:tensorflow:nll_loss = 8498.02, kl_w = 0.39571938, kl_loss = 1491.5498 (73.654 sec)
# INFO:tensorflow:global_step/sec: 1.39271
# INFO:tensorflow:loss = 9045.026, step = 2847 (71.802 sec)
# INFO:tensorflow:nll_loss = 8394.768, kl_w = 0.43618327, kl_loss = 1490.7925 (71.802 sec)
# INFO:tensorflow:global_step/sec: 1.3769
# INFO:tensorflow:loss = 8541.766, step = 2947 (72.627 sec)
# INFO:tensorflow:nll_loss = 7847.3887, kl_w = 0.47751516, kl_loss = 1454.1465 (72.627 sec)
# INFO:tensorflow:global_step/sec: 1.38638
# INFO:tensorflow:loss = 8653.194, step = 3047 (72.131 sec)
# INFO:tensorflow:nll_loss = 7933.1475, kl_w = 0.5191573, kl_loss = 1386.9524 (72.131 sec)
# INFO:tensorflow:Saving checkpoints for 3128 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:Loss for final step: 2173.6084.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-3128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i first saw this film and i thought of the first time of the <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a lot of those movies for this film and it was <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-3128
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3129 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:loss = 9640.709, step = 3129
# INFO:tensorflow:nll_loss = 8896.069, kl_w = 0.55313194, kl_loss = 1346.2236
# INFO:tensorflow:global_step/sec: 1.43804
# INFO:tensorflow:loss = 8853.329, step = 3229 (69.540 sec)
# INFO:tensorflow:nll_loss = 8104.5596, kl_w = 0.5938731, kl_loss = 1260.8242 (69.540 sec)
# INFO:tensorflow:global_step/sec: 1.32672
# INFO:tensorflow:loss = 8518.785, step = 3329 (75.374 sec)
# INFO:tensorflow:nll_loss = 7778.4478, kl_w = 0.6333619, kl_loss = 1168.901 (75.375 sec)
# INFO:tensorflow:global_step/sec: 1.3571
# INFO:tensorflow:loss = 8424.702, step = 3429 (73.686 sec)
# INFO:tensorflow:nll_loss = 7681.6104, kl_w = 0.6711373, kl_loss = 1107.2131 (73.686 sec)
# INFO:tensorflow:global_step/sec: 1.35359
# INFO:tensorflow:loss = 8456.78, step = 3529 (73.878 sec)
# INFO:tensorflow:nll_loss = 7701.371, kl_w = 0.7068222, kl_loss = 1068.7395 (73.877 sec)
# INFO:tensorflow:global_step/sec: 1.32409
# INFO:tensorflow:loss = 9242.417, step = 3629 (75.523 sec)
# INFO:tensorflow:nll_loss = 8502.008, kl_w = 0.7401343, kl_loss = 1000.3711 (75.523 sec)
# INFO:tensorflow:global_step/sec: 1.36703
# INFO:tensorflow:loss = 9295.466, step = 3729 (73.153 sec)
# INFO:tensorflow:nll_loss = 8599.7295, kl_w = 0.7708882, kl_loss = 902.5121 (73.153 sec)
# INFO:tensorflow:global_step/sec: 1.37411
# INFO:tensorflow:loss = 9212.233, step = 3829 (72.774 sec)
# INFO:tensorflow:nll_loss = 8538.381, kl_w = 0.79899096, kl_loss = 843.3799 (72.773 sec)
# INFO:tensorflow:Saving checkpoints for 3910 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:Loss for final step: 2202.3813.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-3910
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i think it was <unk> and i give it a great movie br br <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is so bad and it's not worth a lot of <unk> <unk> <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-3910
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 3911 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:loss = 9045.195, step = 3911
# INFO:tensorflow:nll_loss = 8343.533, kl_w = 0.82004714, kl_loss = 855.636
# INFO:tensorflow:global_step/sec: 1.36262
# INFO:tensorflow:loss = 8478.642, step = 4011 (73.389 sec)
# INFO:tensorflow:nll_loss = 7743.502, kl_w = 0.84334546, kl_loss = 871.69507 (73.389 sec)
# INFO:tensorflow:global_step/sec: 1.32364
# INFO:tensorflow:loss = 8540.185, step = 4111 (75.551 sec)
# INFO:tensorflow:nll_loss = 7836.381, kl_w = 0.8641271, kl_loss = 814.46826 (75.551 sec)
# INFO:tensorflow:global_step/sec: 1.33681
# INFO:tensorflow:loss = 8494.422, step = 4211 (74.804 sec)
# INFO:tensorflow:nll_loss = 7833.577, kl_w = 0.88253593, kl_loss = 748.8023 (74.804 sec)
# INFO:tensorflow:global_step/sec: 1.29077
# INFO:tensorflow:loss = 9147.455, step = 4311 (77.473 sec)
# INFO:tensorflow:nll_loss = 8580.652, kl_w = 0.89874285, kl_loss = 630.66223 (77.473 sec)
# INFO:tensorflow:global_step/sec: 1.28852
# INFO:tensorflow:loss = 9350.068, step = 4411 (77.609 sec)
# INFO:tensorflow:nll_loss = 8812.396, kl_w = 0.9129343, kl_loss = 588.9486 (77.610 sec)
# INFO:tensorflow:global_step/sec: 1.27374
# INFO:tensorflow:loss = 9251.111, step = 4511 (78.508 sec)
# INFO:tensorflow:nll_loss = 8744.496, kl_w = 0.92530197, kl_loss = 547.5135 (78.507 sec)
# INFO:tensorflow:global_step/sec: 1.28186
# INFO:tensorflow:loss = 9090.551, step = 4611 (78.012 sec)
# INFO:tensorflow:nll_loss = 8625.075, kl_w = 0.93603605, kl_loss = 497.28363 (78.011 sec)
# INFO:tensorflow:Saving checkpoints for 4692 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:Loss for final step: 2272.1453.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-4692
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i saw this film at the first time and i saw it in the <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a waste of time and i don't think that this movie <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-4692
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 4693 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:loss = 8526.995, step = 4693
# INFO:tensorflow:nll_loss = 8031.952, kl_w = 0.94374704, kl_loss = 524.55035
# INFO:tensorflow:global_step/sec: 1.38042
# INFO:tensorflow:loss = 8224.195, step = 4793 (72.443 sec)
# INFO:tensorflow:nll_loss = 7727.8643, kl_w = 0.95196813, kl_loss = 521.37354 (72.443 sec)
# INFO:tensorflow:global_step/sec: 1.20638
# INFO:tensorflow:loss = 8249.536, step = 4893 (82.893 sec)
# INFO:tensorflow:nll_loss = 7746.508, kl_w = 0.9590399, kl_loss = 524.5127 (82.893 sec)
# INFO:tensorflow:global_step/sec: 1.3013
# INFO:tensorflow:loss = 9045.297, step = 4993 (76.846 sec)
# INFO:tensorflow:nll_loss = 8604.187, kl_w = 0.9651086, kl_loss = 457.05807 (76.845 sec)
# INFO:tensorflow:global_step/sec: 1.38812
# INFO:tensorflow:loss = 9021.259, step = 5093 (72.040 sec)
# INFO:tensorflow:nll_loss = 8634.3, kl_w = 0.97030604, kl_loss = 398.80124 (72.040 sec)
# INFO:tensorflow:global_step/sec: 1.29323
# INFO:tensorflow:loss = 8653.621, step = 5193 (77.326 sec)
# INFO:tensorflow:nll_loss = 8298.887, kl_w = 0.97474945, kl_loss = 363.92407 (77.326 sec)
# INFO:tensorflow:global_step/sec: 1.45447
# INFO:tensorflow:loss = 8878.26, step = 5293 (68.754 sec)
# INFO:tensorflow:nll_loss = 8523.314, kl_w = 0.9785427, kl_loss = 362.72894 (68.754 sec)
# INFO:tensorflow:global_step/sec: 1.18045
# INFO:tensorflow:loss = 8260.672, step = 5393 (84.714 sec)
# INFO:tensorflow:nll_loss = 7899.316, kl_w = 0.9817768, kl_loss = 368.06277 (84.715 sec)
# INFO:tensorflow:Saving checkpoints for 5466 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 5474 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:Loss for final step: 2019.9547.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-5474
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i had to admit that this was the best film i have ever seen <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is a great example of the plot and a lot of people <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-5474
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 5475 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:loss = 8009.133, step = 5475
# INFO:tensorflow:nll_loss = 7636.264, kl_w = 0.98406756, kl_loss = 378.90552
# INFO:tensorflow:global_step/sec: 1.35093
# INFO:tensorflow:loss = 8179.802, step = 5575 (74.026 sec)
# INFO:tensorflow:nll_loss = 7818.538, kl_w = 0.9864804, kl_loss = 366.21466 (74.027 sec)
# INFO:tensorflow:global_step/sec: 1.09446
# INFO:tensorflow:loss = 7899.781, step = 5675 (91.368 sec)
# INFO:tensorflow:nll_loss = 7567.182, kl_w = 0.98853207, kl_loss = 336.45728 (91.367 sec)
# INFO:tensorflow:global_step/sec: 1.29674
# INFO:tensorflow:loss = 8890.498, step = 5775 (77.116 sec)
# INFO:tensorflow:nll_loss = 8599.896, kl_w = 0.9902755, kl_loss = 293.4549 (77.116 sec)
# INFO:tensorflow:global_step/sec: 1.21839
# INFO:tensorflow:loss = 8653.213, step = 5875 (82.075 sec)
# INFO:tensorflow:nll_loss = 8377.488, kl_w = 0.9917561, kl_loss = 278.01642 (82.075 sec)
# INFO:tensorflow:global_step/sec: 1.23008
# INFO:tensorflow:loss = 8497.692, step = 5975 (81.295 sec)
# INFO:tensorflow:nll_loss = 8257.935, kl_w = 0.99301285, kl_loss = 241.44498 (81.295 sec)
# INFO:tensorflow:global_step/sec: 1.07853
# INFO:tensorflow:loss = 8635.825, step = 6075 (92.720 sec)
# INFO:tensorflow:nll_loss = 8385.575, kl_w = 0.9940791, kl_loss = 251.74017 (92.720 sec)
# INFO:tensorflow:global_step/sec: 1.10485
# INFO:tensorflow:loss = 8227.5625, step = 6175 (90.509 sec)
# INFO:tensorflow:nll_loss = 7950.5205, kl_w = 0.99498355, kl_loss = 278.43863 (90.508 sec)
# INFO:tensorflow:Saving checkpoints for 6186 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 6256 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:Loss for final step: 2123.8623.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-6256
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i saw this movie when i first saw the first time i saw it <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this movie is not the worst movie i have ever seen in my life <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-6256
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 6257 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:loss = 8104.8364, step = 6257
# INFO:tensorflow:nll_loss = 7852.044, kl_w = 0.9956215, kl_loss = 253.90399
# INFO:tensorflow:global_step/sec: 1.11472
# INFO:tensorflow:loss = 8123.179, step = 6357 (89.710 sec)
# INFO:tensorflow:nll_loss = 7845.906, kl_w = 0.9962913, kl_loss = 278.30542 (89.710 sec)
# INFO:tensorflow:global_step/sec: 1.09031
# INFO:tensorflow:loss = 7895.385, step = 6457 (91.717 sec)
# INFO:tensorflow:nll_loss = 7644.1904, kl_w = 0.99685884, kl_loss = 251.98608 (91.718 sec)
# INFO:tensorflow:global_step/sec: 1.1542
# INFO:tensorflow:loss = 8890.087, step = 6557 (86.640 sec)
# INFO:tensorflow:nll_loss = 8674.417, kl_w = 0.9973398, kl_loss = 216.24522 (86.639 sec)
# INFO:tensorflow:global_step/sec: 1.18446
# INFO:tensorflow:loss = 8700.064, step = 6657 (84.427 sec)
# INFO:tensorflow:nll_loss = 8503.529, kl_w = 0.99774724, kl_loss = 196.9786 (84.428 sec)
# INFO:tensorflow:global_step/sec: 1.26983
# INFO:tensorflow:loss = 8685.513, step = 6757 (78.750 sec)
# INFO:tensorflow:nll_loss = 8503.842, kl_w = 0.99809235, kl_loss = 182.01797 (78.750 sec)
# INFO:tensorflow:global_step/sec: 1.32334
# INFO:tensorflow:loss = 8350.937, step = 6857 (75.566 sec)
# INFO:tensorflow:nll_loss = 8167.114, kl_w = 0.99838483, kl_loss = 184.12032 (75.566 sec)
# INFO:tensorflow:global_step/sec: 1.4608
# INFO:tensorflow:loss = 8127.2705, step = 6957 (68.456 sec)
# INFO:tensorflow:nll_loss = 7925.819, kl_w = 0.9986324, kl_loss = 201.72754 (68.456 sec)
# INFO:tensorflow:Saving checkpoints for 6989 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:Saving checkpoints for 7038 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:Loss for final step: 2108.7988.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-7038
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: this is one of the worst movies ever made for tv and it is <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is the worst movie i've ever seen and i have ever seen it <end>
#
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-7038
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 7039 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:loss = 8168.731, step = 7039
# INFO:tensorflow:nll_loss = 7972.55, kl_w = 0.99880695, kl_loss = 196.41534
# INFO:tensorflow:global_step/sec: 1.51218
# INFO:tensorflow:loss = 8064.7627, step = 7139 (66.131 sec)
# INFO:tensorflow:nll_loss = 7864.509, kl_w = 0.9989899, kl_loss = 200.45648 (66.131 sec)
# INFO:tensorflow:global_step/sec: 1.4302
# INFO:tensorflow:loss = 7978.064, step = 7239 (69.920 sec)
# INFO:tensorflow:nll_loss = 7791.3647, kl_w = 0.9991448, kl_loss = 186.85905 (69.920 sec)
# INFO:tensorflow:global_step/sec: 1.41611
# INFO:tensorflow:loss = 7989.3276, step = 7339 (70.616 sec)
# INFO:tensorflow:nll_loss = 7796.208, kl_w = 0.999276, kl_loss = 193.25974 (70.616 sec)
# INFO:tensorflow:global_step/sec: 1.36337
# INFO:tensorflow:loss = 8486.166, step = 7439 (73.348 sec)
# INFO:tensorflow:nll_loss = 8324.786, kl_w = 0.999387, kl_loss = 161.47867 (73.348 sec)
# INFO:tensorflow:global_step/sec: 1.39131
# INFO:tensorflow:loss = 8343.274, step = 7539 (71.874 sec)
# INFO:tensorflow:nll_loss = 8198.216, kl_w = 0.99948114, kl_loss = 145.13376 (71.875 sec)
# INFO:tensorflow:global_step/sec: 1.37241
# INFO:tensorflow:loss = 8511.752, step = 7639 (72.865 sec)
# INFO:tensorflow:nll_loss = 8385.664, kl_w = 0.9995608, kl_loss = 126.14352 (72.865 sec)
# INFO:tensorflow:global_step/sec: 1.39982
# INFO:tensorflow:loss = 8508.579, step = 7739 (71.438 sec)
# INFO:tensorflow:nll_loss = 8381.818, kl_w = 0.9996282, kl_loss = 126.80742 (71.438 sec)
# INFO:tensorflow:Saving checkpoints for 7820 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt.
# INFO:tensorflow:Loss for final step: 2083.8992.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmp6xbpjdax/model.ckpt-7820
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
#
# Original: i love this film and i think it is one of the best films
# Reconstr: i saw this movie when i was a kid i saw it at the <end>
#
# Original: this movie is a waste of time and there is no point to watch it
# Reconstr: this is one of the worst movies i've ever seen i have ever seen <end>
