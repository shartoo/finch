# %% [markdown]
# Notebook written by [Zhedong Zheng](https://github.com/zhedongzheng)
#
# ![title](img/word2vec.png)

# %%
from collections import Counter

import tensorflow as tf
import numpy as np
import re

# %%
PARAMS = {
    'min_freq': 5,
    'window_size': 3,
    'n_sampled': 100,
    'embed_dim': 200,
    'sample_words': ['six', 'gold', 'japan', 'college'],
    'batch_size': 1000,
    'n_epochs': 20,
}

# %%
def preprocess_text(text):
    text = text.replace('\n', ' ')
    text = re.sub('\s+', ' ', text).strip().lower()

    words = text.split()
    word2freq = Counter(words)
    words = [word for word in words if word2freq[word] > PARAMS['min_freq']]
    print("Total words:", len(words))

    _words = set(words)
    PARAMS['word2idx'] = {c: i for i, c in enumerate(_words)}
    PARAMS['idx2word'] = {i: c for i, c in enumerate(_words)}
    PARAMS['vocab_size'] = len(PARAMS['idx2word'])
    print('Vocabulary size:', PARAMS['vocab_size'])

    indexed = [PARAMS['word2idx'][w] for w in words]
    indexed = filter_high_freq(indexed)
    print("Word preprocessing completed ...")
    
    return indexed

def filter_high_freq(int_words, t=1e-5, threshold=0.8):
    int_word_counts = Counter(int_words)
    total_count = len(int_words)

    word_freqs = {w: c / total_count for w, c in int_word_counts.items()}
    prob_drop = {w: 1 - np.sqrt(t / word_freqs[w]) for w in int_word_counts}
    train_words = [w for w in int_words if prob_drop[w] < threshold]

    return train_words

def make_data(int_words):
    x, y = [], []
    for i in range(PARAMS['window_size'], len(int_words)-PARAMS['window_size']):
        inputs = get_x(int_words, i)
        x.append(inputs)
        y.append(int_words[i])
    return np.array(x), np.array(y)

def get_x(words, idx):
    left = idx - PARAMS['window_size']
    right = idx + PARAMS['window_size']
    return words[left: idx] + words[idx+1: right+1]

# %%
def model_fn(features, labels, mode, params):
    W = tf.get_variable('softmax_W', [PARAMS['vocab_size'], PARAMS['embed_dim']])
    b = tf.get_variable('softmax_b', [PARAMS['vocab_size']])
    E = tf.get_variable('embedding', [PARAMS['vocab_size'], PARAMS['embed_dim']])
    embedded = tf.nn.embedding_lookup(E, features) # forward activation
    embedded = tf.reduce_mean(embedded, [1])
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        loss_op = tf.reduce_mean(tf.nn.sampled_softmax_loss(
            weights = W,
            biases = b,
            labels = labels,
            inputs = embedded,
            num_sampled = PARAMS['n_sampled'],
            num_classes = PARAMS['vocab_size']))

        train_op = tf.train.AdamOptimizer().minimize(
            loss_op, global_step=tf.train.get_global_step())
        
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss_op, train_op=train_op)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        normalized_E = tf.nn.l2_normalize(E, -1)
        sample_E = tf.nn.embedding_lookup(normalized_E, features)
        similarity = tf.matmul(sample_E, normalized_E, transpose_b=True)
        
        return tf.estimator.EstimatorSpec(mode, predictions=similarity)
    

def print_neighbours(similarity, top_k=5):
    for i in range(len(PARAMS['sample_words'])):
        neighbours = (-similarity[i]).argsort()[1:top_k+1]
        log = 'Nearest to [%s]:' % PARAMS['sample_words'][i]
        for k in range(top_k):
            neighbour = PARAMS['idx2word'][neighbours[k]]
            log = '%s %s,' % (log, neighbour)
        print(log)

# %%
with open('temp/ptb_train.txt') as f:
    x_train, y_train = make_data(preprocess_text(f.read()))

estimator = tf.estimator.Estimator(model_fn)

estimator.train(tf.estimator.inputs.numpy_input_fn(
    x_train, np.expand_dims(y_train, -1),
    batch_size = PARAMS['batch_size'],
    num_epochs = PARAMS['n_epochs'],
    shuffle = True))

sim = np.array(list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
    x = np.array([PARAMS['word2idx'][w] for w in PARAMS['sample_words']]),
    shuffle = False))))

print_neighbours(sim)
# Out:
# Total words: 885720
# Vocabulary size: 9582
# Word preprocessing completed ...
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpuks8iym3
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpuks8iym3', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1132cb2b0>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function model_fn at 0x1132bd8c8>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From /usr/local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1346: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.
#
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpuks8iym3/model.ckpt.
# INFO:tensorflow:loss = 3.8350616, step = 1
# INFO:tensorflow:global_step/sec: 40.7025
# INFO:tensorflow:loss = 3.636289, step = 101 (2.458 sec)
# INFO:tensorflow:global_step/sec: 39.3896
# INFO:tensorflow:loss = 3.544359, step = 201 (2.538 sec)
# INFO:tensorflow:global_step/sec: 42.0322
# INFO:tensorflow:loss = 3.7118027, step = 301 (2.380 sec)
# INFO:tensorflow:global_step/sec: 44.6294
# INFO:tensorflow:loss = 3.478565, step = 401 (2.240 sec)
# INFO:tensorflow:global_step/sec: 41.4182
# INFO:tensorflow:loss = 3.0353925, step = 501 (2.414 sec)
# INFO:tensorflow:global_step/sec: 47.126
# INFO:tensorflow:loss = 3.5636275, step = 601 (2.122 sec)
# INFO:tensorflow:global_step/sec: 39.8924
# INFO:tensorflow:loss = 3.1482036, step = 701 (2.507 sec)
# INFO:tensorflow:global_step/sec: 40.1808
# INFO:tensorflow:loss = 3.3421412, step = 801 (2.489 sec)
# INFO:tensorflow:global_step/sec: 36.6331
# INFO:tensorflow:loss = 3.0614142, step = 901 (2.730 sec)
# INFO:tensorflow:global_step/sec: 40.4399
# INFO:tensorflow:loss = 2.7809231, step = 1001 (2.473 sec)
# INFO:tensorflow:global_step/sec: 43.8506
# INFO:tensorflow:loss = 3.7473638, step = 1101 (2.280 sec)
# INFO:tensorflow:global_step/sec: 42.3958
# INFO:tensorflow:loss = 3.2437446, step = 1201 (2.359 sec)
# INFO:tensorflow:global_step/sec: 43.7953
# INFO:tensorflow:loss = 2.8726132, step = 1301 (2.283 sec)
# INFO:tensorflow:global_step/sec: 38.4877
# INFO:tensorflow:loss = 3.0492775, step = 1401 (2.598 sec)
# INFO:tensorflow:global_step/sec: 37.9712
# INFO:tensorflow:loss = 2.548696, step = 1501 (2.634 sec)
# INFO:tensorflow:global_step/sec: 43.5196
# INFO:tensorflow:loss = 3.1152203, step = 1601 (2.297 sec)
# INFO:tensorflow:global_step/sec: 44.3791
# INFO:tensorflow:loss = 3.097227, step = 1701 (2.254 sec)
# INFO:tensorflow:global_step/sec: 44.0748
# INFO:tensorflow:loss = 3.764312, step = 1801 (2.269 sec)
# INFO:tensorflow:global_step/sec: 41.915
# INFO:tensorflow:loss = 3.4257622, step = 1901 (2.385 sec)
# INFO:tensorflow:global_step/sec: 40.8742
# INFO:tensorflow:loss = 2.9248288, step = 2001 (2.446 sec)
# INFO:tensorflow:global_step/sec: 41.9666
# INFO:tensorflow:loss = 3.0322022, step = 2101 (2.383 sec)
# INFO:tensorflow:global_step/sec: 40.4418
# INFO:tensorflow:loss = 2.6801634, step = 2201 (2.473 sec)
# INFO:tensorflow:global_step/sec: 40.3394
# INFO:tensorflow:loss = 3.1094692, step = 2301 (2.479 sec)
# INFO:tensorflow:global_step/sec: 41.3432
# INFO:tensorflow:loss = 2.4879048, step = 2401 (2.419 sec)
# INFO:tensorflow:global_step/sec: 44.4895
# INFO:tensorflow:loss = 3.0866075, step = 2501 (2.248 sec)
# INFO:tensorflow:global_step/sec: 43.7445
# INFO:tensorflow:loss = 2.580624, step = 2601 (2.286 sec)
# INFO:tensorflow:global_step/sec: 42.9485
# INFO:tensorflow:loss = 2.52849, step = 2701 (2.328 sec)
# INFO:tensorflow:global_step/sec: 37.6309
# INFO:tensorflow:loss = 2.4887617, step = 2801 (2.657 sec)
# INFO:tensorflow:global_step/sec: 41.7951
# INFO:tensorflow:loss = 2.324918, step = 2901 (2.392 sec)
# INFO:tensorflow:global_step/sec: 40.9469
# INFO:tensorflow:loss = 2.5941117, step = 3001 (2.442 sec)
# INFO:tensorflow:global_step/sec: 41.1171
# INFO:tensorflow:loss = 2.5638657, step = 3101 (2.432 sec)
# INFO:tensorflow:global_step/sec: 41.7107
# INFO:tensorflow:loss = 1.9251391, step = 3201 (2.397 sec)
# INFO:tensorflow:global_step/sec: 41.1085
# INFO:tensorflow:loss = 2.2546482, step = 3301 (2.432 sec)
# INFO:tensorflow:global_step/sec: 44.6187
# INFO:tensorflow:loss = 2.5781186, step = 3401 (2.241 sec)
# INFO:tensorflow:global_step/sec: 40.8683
# INFO:tensorflow:loss = 2.6886415, step = 3501 (2.447 sec)
# INFO:tensorflow:global_step/sec: 37.0906
# INFO:tensorflow:loss = 2.0682976, step = 3601 (2.696 sec)
# INFO:tensorflow:global_step/sec: 37.0081
# INFO:tensorflow:loss = 2.445887, step = 3701 (2.702 sec)
# INFO:tensorflow:global_step/sec: 41.1656
# INFO:tensorflow:loss = 2.5939693, step = 3801 (2.429 sec)
# INFO:tensorflow:global_step/sec: 42.7482
# INFO:tensorflow:loss = 2.655304, step = 3901 (2.339 sec)
# INFO:tensorflow:global_step/sec: 39.7098
# INFO:tensorflow:loss = 2.252564, step = 4001 (2.519 sec)
# INFO:tensorflow:global_step/sec: 32.271
# INFO:tensorflow:loss = 1.6980852, step = 4101 (3.098 sec)
# INFO:tensorflow:global_step/sec: 40.6962
# INFO:tensorflow:loss = 2.4039032, step = 4201 (2.457 sec)
# INFO:tensorflow:global_step/sec: 42.0593
# INFO:tensorflow:loss = 2.2756357, step = 4301 (2.377 sec)
# INFO:tensorflow:global_step/sec: 40.2766
# INFO:tensorflow:loss = 1.9164715, step = 4401 (2.483 sec)
# INFO:tensorflow:global_step/sec: 43.4905
# INFO:tensorflow:loss = 2.1856148, step = 4501 (2.299 sec)
# INFO:tensorflow:global_step/sec: 42.8171
# INFO:tensorflow:loss = 2.6216207, step = 4601 (2.336 sec)
# INFO:tensorflow:global_step/sec: 40.6165
# INFO:tensorflow:loss = 1.9581236, step = 4701 (2.462 sec)
# INFO:tensorflow:global_step/sec: 38.0454
# INFO:tensorflow:loss = 2.1972666, step = 4801 (2.628 sec)
# INFO:tensorflow:global_step/sec: 41.7592
# INFO:tensorflow:loss = 3.5713267, step = 4901 (2.395 sec)
# INFO:tensorflow:global_step/sec: 42.3471
# INFO:tensorflow:loss = 2.3030143, step = 5001 (2.361 sec)
# INFO:tensorflow:global_step/sec: 47.7142
# INFO:tensorflow:loss = 1.8831947, step = 5101 (2.096 sec)
# INFO:tensorflow:global_step/sec: 47.6745
# INFO:tensorflow:loss = 1.7045817, step = 5201 (2.098 sec)
# INFO:tensorflow:global_step/sec: 44.1917
# INFO:tensorflow:loss = 1.6338967, step = 5301 (2.263 sec)
# INFO:tensorflow:Saving checkpoints for 5396 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpuks8iym3/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.7628521.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpuks8iym3/model.ckpt-5396
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Nearest to [six]: insurance, both, page-one, hospital, focuses,
# Nearest to [gold]: ounce, ounces, platinum, silver, bullion,
# Nearest to [japan]: iron, snapped, unrest, opening, or,
# Nearest to [college]: football, school, teaches, sports, basketball,
