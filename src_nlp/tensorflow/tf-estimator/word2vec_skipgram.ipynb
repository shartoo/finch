# %% [markdown]
# Notebook written by [Zhedong Zheng](https://github.com/zhedongzheng)
#
# ![title](img/word2vec.png)

# %%
from collections import Counter

import tensorflow as tf
import numpy as np
import re

# %%
PARAMS = {
    'min_freq': 5,
    'skip_window': 5,
    'n_sampled': 100,
    'embed_dim': 200,
    'sample_words': ['six', 'gold', 'japan', 'college'],
    'batch_size': 1000,
    'n_epochs': 10,
}

# %%
def preprocess_text(text):
    text = text.replace('\n', ' ')
    text = re.sub('\s+', ' ', text).strip().lower()

    words = text.split()
    word2freq = Counter(words)
    words = [word for word in words if word2freq[word] > PARAMS['min_freq']]
    print("Total words:", len(words))

    _words = set(words)
    PARAMS['word2idx'] = {c: i for i, c in enumerate(_words)}
    PARAMS['idx2word'] = {i: c for i, c in enumerate(_words)}
    PARAMS['vocab_size'] = len(PARAMS['idx2word'])
    print('Vocabulary size:', PARAMS['vocab_size'])

    indexed = [PARAMS['word2idx'][w] for w in words]
    indexed = filter_high_freq(indexed)
    print("Word preprocessing completed ...")
    
    return indexed

def filter_high_freq(int_words, t=1e-5, threshold=0.8):
    int_word_counts = Counter(int_words)
    total_count = len(int_words)

    word_freqs = {w: c / total_count for w, c in int_word_counts.items()}
    prob_drop = {w: 1 - np.sqrt(t / word_freqs[w]) for w in int_word_counts}
    train_words = [w for w in int_words if prob_drop[w] < threshold]

    return train_words

def make_data(int_words):
    x, y = [], []
    for i in range(0, len(int_words)):
        input_w = int_words[i]
        labels = get_y(int_words, i)
        x.extend([input_w] * len(labels))
        y.extend(labels)
    return x, y


def get_y(words, idx):
    skip_window = np.random.randint(1, PARAMS['skip_window']+1)
    left = idx - skip_window if (idx - skip_window) > 0 else 0
    right = idx + skip_window
    y = words[left: idx] + words[idx+1: right+1]
    return list(set(y))

# %%
def model_fn(features, labels, mode, params):
    W = tf.get_variable('softmax_W', [PARAMS['vocab_size'], PARAMS['embed_dim']])
    b = tf.get_variable('softmax_b', [PARAMS['vocab_size']])
    E = tf.get_variable('embedding', [PARAMS['vocab_size'], PARAMS['embed_dim']])
    embedded = tf.nn.embedding_lookup(E, features) # forward activation
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        loss_op = tf.reduce_mean(tf.nn.sampled_softmax_loss(
            weights = W,
            biases = b,
            labels = labels,
            inputs = embedded,
            num_sampled = PARAMS['n_sampled'],
            num_classes = PARAMS['vocab_size']))

        train_op = tf.train.AdamOptimizer().minimize(
            loss_op, global_step=tf.train.get_global_step())
        
        return tf.estimator.EstimatorSpec(mode=mode, loss=loss_op, train_op=train_op)
    
    if mode == tf.estimator.ModeKeys.PREDICT:
        normalized_E = tf.nn.l2_normalize(E, -1)
        sample_E = tf.nn.embedding_lookup(normalized_E, features)
        similarity = tf.matmul(sample_E, normalized_E, transpose_b=True)
        
        return tf.estimator.EstimatorSpec(mode, predictions=similarity)
    

def print_neighbours(similarity, top_k=5):
    for i in range(len(PARAMS['sample_words'])):
        neighbours = (-similarity[i]).argsort()[1:top_k+1]
        log = 'Nearest to [%s]:' % PARAMS['sample_words'][i]
        for k in range(top_k):
            neighbour = PARAMS['idx2word'][neighbours[k]]
            log = '%s %s,' % (log, neighbour)
        print(log)

# %%
with open('temp/ptb_train.txt') as f:
    x_train, y_train = make_data(preprocess_text(f.read()))

estimator = tf.estimator.Estimator(model_fn)

estimator.train(tf.estimator.inputs.numpy_input_fn(
    np.array(x_train), np.expand_dims(y_train, -1),
    batch_size = PARAMS['batch_size'],
    num_epochs = PARAMS['n_epochs'],
    shuffle = True))

sim = np.array(list(estimator.predict(tf.estimator.inputs.numpy_input_fn(
    x = np.array([PARAMS['word2idx'][w] for w in PARAMS['sample_words']]),
    shuffle = False))))

print_neighbours(sim)
# Out:
# Total words: 885720
# Vocabulary size: 9582
# Word preprocessing completed ...
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpy7np20if
# INFO:tensorflow:Using config: {'_model_dir': '/var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpy7np20if', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x103c345f8>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# WARNING:tensorflow:Estimator's model_fn (<function model_fn at 0x1163479d8>) includes params argument, but params are not passed to Estimator.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpy7np20if/model.ckpt.
# INFO:tensorflow:loss = 3.572584, step = 1
# INFO:tensorflow:global_step/sec: 57.907
# INFO:tensorflow:loss = 3.4585214, step = 101 (1.728 sec)
# INFO:tensorflow:global_step/sec: 60.3552
# INFO:tensorflow:loss = 3.7576487, step = 201 (1.657 sec)
# INFO:tensorflow:global_step/sec: 56.3605
# INFO:tensorflow:loss = 3.741787, step = 301 (1.774 sec)
# INFO:tensorflow:global_step/sec: 59.7878
# INFO:tensorflow:loss = 3.5180776, step = 401 (1.673 sec)
# INFO:tensorflow:global_step/sec: 58.5461
# INFO:tensorflow:loss = 3.2163436, step = 501 (1.709 sec)
# INFO:tensorflow:global_step/sec: 57.9363
# INFO:tensorflow:loss = 3.0812793, step = 601 (1.726 sec)
# INFO:tensorflow:global_step/sec: 58.4728
# INFO:tensorflow:loss = 3.2797124, step = 701 (1.710 sec)
# INFO:tensorflow:global_step/sec: 54.9508
# INFO:tensorflow:loss = 3.9501016, step = 801 (1.820 sec)
# INFO:tensorflow:global_step/sec: 58.6314
# INFO:tensorflow:loss = 3.2774668, step = 901 (1.706 sec)
# INFO:tensorflow:global_step/sec: 57.776
# INFO:tensorflow:loss = 3.7374582, step = 1001 (1.731 sec)
# INFO:tensorflow:global_step/sec: 57.9331
# INFO:tensorflow:loss = 4.3138857, step = 1101 (1.726 sec)
# INFO:tensorflow:global_step/sec: 59.1636
# INFO:tensorflow:loss = 3.3252807, step = 1201 (1.690 sec)
# INFO:tensorflow:global_step/sec: 59.4529
# INFO:tensorflow:loss = 3.2588108, step = 1301 (1.682 sec)
# INFO:tensorflow:global_step/sec: 62.0307
# INFO:tensorflow:loss = 3.2870162, step = 1401 (1.612 sec)
# INFO:tensorflow:global_step/sec: 58.4416
# INFO:tensorflow:loss = 2.9736738, step = 1501 (1.711 sec)
# INFO:tensorflow:global_step/sec: 58.35
# INFO:tensorflow:loss = 2.993894, step = 1601 (1.714 sec)
# INFO:tensorflow:global_step/sec: 57.7948
# INFO:tensorflow:loss = 3.391178, step = 1701 (1.730 sec)
# INFO:tensorflow:global_step/sec: 62.8399
# INFO:tensorflow:loss = 3.506293, step = 1801 (1.591 sec)
# INFO:tensorflow:global_step/sec: 62.7704
# INFO:tensorflow:loss = 3.551006, step = 1901 (1.593 sec)
# INFO:tensorflow:global_step/sec: 62.9658
# INFO:tensorflow:loss = 3.304871, step = 2001 (1.588 sec)
# INFO:tensorflow:global_step/sec: 62.1802
# INFO:tensorflow:loss = 3.1726358, step = 2101 (1.608 sec)
# INFO:tensorflow:global_step/sec: 58.2949
# INFO:tensorflow:loss = 3.0341074, step = 2201 (1.716 sec)
# INFO:tensorflow:global_step/sec: 56.7368
# INFO:tensorflow:loss = 3.4992177, step = 2301 (1.762 sec)
# INFO:tensorflow:global_step/sec: 55.5062
# INFO:tensorflow:loss = 3.412107, step = 2401 (1.801 sec)
# INFO:tensorflow:global_step/sec: 58.8862
# INFO:tensorflow:loss = 3.1843443, step = 2501 (1.698 sec)
# INFO:tensorflow:global_step/sec: 60.7569
# INFO:tensorflow:loss = 2.9348187, step = 2601 (1.646 sec)
# INFO:tensorflow:global_step/sec: 60.9089
# INFO:tensorflow:loss = 3.1166327, step = 2701 (1.642 sec)
# INFO:tensorflow:global_step/sec: 60.5324
# INFO:tensorflow:loss = 3.1383488, step = 2801 (1.652 sec)
# INFO:tensorflow:global_step/sec: 58.0511
# INFO:tensorflow:loss = 4.4421372, step = 2901 (1.723 sec)
# INFO:tensorflow:global_step/sec: 59.2842
# INFO:tensorflow:loss = 3.5164413, step = 3001 (1.687 sec)
# INFO:tensorflow:global_step/sec: 56.4967
# INFO:tensorflow:loss = 3.3149545, step = 3101 (1.770 sec)
# INFO:tensorflow:global_step/sec: 56.8748
# INFO:tensorflow:loss = 3.3681548, step = 3201 (1.758 sec)
# INFO:tensorflow:global_step/sec: 56.4892
# INFO:tensorflow:loss = 3.4943812, step = 3301 (1.770 sec)
# INFO:tensorflow:global_step/sec: 59.0581
# INFO:tensorflow:loss = 3.4897423, step = 3401 (1.693 sec)
# INFO:tensorflow:global_step/sec: 58.5714
# INFO:tensorflow:loss = 3.8837757, step = 3501 (1.708 sec)
# INFO:tensorflow:global_step/sec: 57.862
# INFO:tensorflow:loss = 3.3958774, step = 3601 (1.728 sec)
# INFO:tensorflow:global_step/sec: 59.8979
# INFO:tensorflow:loss = 2.6135135, step = 3701 (1.670 sec)
# INFO:tensorflow:global_step/sec: 60.2582
# INFO:tensorflow:loss = 2.6331487, step = 3801 (1.659 sec)
# INFO:tensorflow:global_step/sec: 57.5301
# INFO:tensorflow:loss = 3.3353598, step = 3901 (1.738 sec)
# INFO:tensorflow:global_step/sec: 60.787
# INFO:tensorflow:loss = 2.4888847, step = 4001 (1.645 sec)
# INFO:tensorflow:global_step/sec: 54.8256
# INFO:tensorflow:loss = 2.7606478, step = 4101 (1.824 sec)
# INFO:tensorflow:global_step/sec: 60.0129
# INFO:tensorflow:loss = 2.7815375, step = 4201 (1.666 sec)
# INFO:tensorflow:global_step/sec: 54.5061
# INFO:tensorflow:loss = 3.4804556, step = 4301 (1.835 sec)
# INFO:tensorflow:global_step/sec: 57.4321
# INFO:tensorflow:loss = 2.3585453, step = 4401 (1.741 sec)
# INFO:tensorflow:global_step/sec: 58.0627
# INFO:tensorflow:loss = 2.8821292, step = 4501 (1.722 sec)
# INFO:tensorflow:global_step/sec: 58.6357
# INFO:tensorflow:loss = 3.12492, step = 4601 (1.705 sec)
# INFO:tensorflow:global_step/sec: 59.3606
# INFO:tensorflow:loss = 2.9881577, step = 4701 (1.685 sec)
# INFO:tensorflow:global_step/sec: 61.1619
# INFO:tensorflow:loss = 3.094927, step = 4801 (1.635 sec)
# INFO:tensorflow:global_step/sec: 58.5027
# INFO:tensorflow:loss = 2.4716258, step = 4901 (1.709 sec)
# INFO:tensorflow:global_step/sec: 58.4449
# INFO:tensorflow:loss = 2.9468515, step = 5001 (1.711 sec)
# INFO:tensorflow:global_step/sec: 59.9653
# INFO:tensorflow:loss = 3.128043, step = 5101 (1.668 sec)
# INFO:tensorflow:global_step/sec: 58.7358
# INFO:tensorflow:loss = 2.521702, step = 5201 (1.703 sec)
# INFO:tensorflow:global_step/sec: 58.3689
# INFO:tensorflow:loss = 2.9805777, step = 5301 (1.713 sec)
# INFO:tensorflow:global_step/sec: 61.1822
# INFO:tensorflow:loss = 3.356373, step = 5401 (1.634 sec)
# INFO:tensorflow:global_step/sec: 60.8209
# INFO:tensorflow:loss = 3.0261474, step = 5501 (1.645 sec)
# INFO:tensorflow:global_step/sec: 50.3665
# INFO:tensorflow:loss = 3.0819232, step = 5601 (1.985 sec)
# INFO:tensorflow:global_step/sec: 61.7315
# INFO:tensorflow:loss = 2.9412625, step = 5701 (1.620 sec)
# INFO:tensorflow:global_step/sec: 59.0804
# INFO:tensorflow:loss = 3.190103, step = 5801 (1.693 sec)
# INFO:tensorflow:global_step/sec: 58.6441
# INFO:tensorflow:loss = 3.0738537, step = 5901 (1.706 sec)
# INFO:tensorflow:global_step/sec: 59.4777
# INFO:tensorflow:loss = 3.1298702, step = 6001 (1.681 sec)
# INFO:tensorflow:global_step/sec: 54.1754
# INFO:tensorflow:loss = 3.0504892, step = 6101 (1.846 sec)
# INFO:tensorflow:global_step/sec: 56.3314
# INFO:tensorflow:loss = 2.6327593, step = 6201 (1.775 sec)
# INFO:tensorflow:global_step/sec: 59.2964
# INFO:tensorflow:loss = 2.9360542, step = 6301 (1.686 sec)
# INFO:tensorflow:global_step/sec: 62.8184
# INFO:tensorflow:loss = 3.122077, step = 6401 (1.592 sec)
# INFO:tensorflow:global_step/sec: 60.8912
# INFO:tensorflow:loss = 2.6558678, step = 6501 (1.642 sec)
# INFO:tensorflow:global_step/sec: 61.6463
# INFO:tensorflow:loss = 2.090322, step = 6601 (1.622 sec)
# INFO:tensorflow:global_step/sec: 59.7329
# INFO:tensorflow:loss = 3.0764005, step = 6701 (1.674 sec)
# INFO:tensorflow:global_step/sec: 59.5193
# INFO:tensorflow:loss = 2.5741773, step = 6801 (1.680 sec)
# INFO:tensorflow:global_step/sec: 61.2971
# INFO:tensorflow:loss = 2.8367689, step = 6901 (1.632 sec)
# INFO:tensorflow:global_step/sec: 60.2653
# INFO:tensorflow:loss = 2.6537147, step = 7001 (1.659 sec)
# INFO:tensorflow:global_step/sec: 61.1669
# INFO:tensorflow:loss = 2.521786, step = 7101 (1.635 sec)
# INFO:tensorflow:global_step/sec: 62.9534
# INFO:tensorflow:loss = 2.553159, step = 7201 (1.588 sec)
# INFO:tensorflow:global_step/sec: 61.0411
# INFO:tensorflow:loss = 3.258956, step = 7301 (1.638 sec)
# INFO:tensorflow:global_step/sec: 60.6392
# INFO:tensorflow:loss = 2.579619, step = 7401 (1.649 sec)
# INFO:tensorflow:global_step/sec: 55.1294
# INFO:tensorflow:loss = 2.4881356, step = 7501 (1.814 sec)
# INFO:tensorflow:global_step/sec: 51.267
# INFO:tensorflow:loss = 2.8275628, step = 7601 (1.951 sec)
# INFO:tensorflow:global_step/sec: 52.6462
# INFO:tensorflow:loss = 2.8788507, step = 7701 (1.900 sec)
# INFO:tensorflow:global_step/sec: 54.4561
# INFO:tensorflow:loss = 2.6664088, step = 7801 (1.836 sec)
# INFO:tensorflow:global_step/sec: 53.8343
# INFO:tensorflow:loss = 3.0394185, step = 7901 (1.858 sec)
# INFO:tensorflow:global_step/sec: 53.1115
# INFO:tensorflow:loss = 3.045693, step = 8001 (1.883 sec)
# INFO:tensorflow:global_step/sec: 58.3542
# INFO:tensorflow:loss = 2.7471213, step = 8101 (1.714 sec)
# INFO:tensorflow:global_step/sec: 60.6618
# INFO:tensorflow:loss = 2.8601131, step = 8201 (1.648 sec)
# INFO:tensorflow:global_step/sec: 58.1732
# INFO:tensorflow:loss = 2.5075586, step = 8301 (1.720 sec)
# INFO:tensorflow:global_step/sec: 50.6544
# INFO:tensorflow:loss = 2.5334792, step = 8401 (1.974 sec)
# INFO:tensorflow:global_step/sec: 53.6944
# INFO:tensorflow:loss = 2.5767972, step = 8501 (1.863 sec)
# INFO:tensorflow:global_step/sec: 57.7763
# INFO:tensorflow:loss = 1.5418891, step = 8601 (1.730 sec)
# INFO:tensorflow:global_step/sec: 60.9193
# INFO:tensorflow:loss = 2.9490523, step = 8701 (1.641 sec)
# INFO:tensorflow:global_step/sec: 58.6214
# INFO:tensorflow:loss = 2.767349, step = 8801 (1.706 sec)
# INFO:tensorflow:global_step/sec: 59.5638
# INFO:tensorflow:loss = 2.2789853, step = 8901 (1.679 sec)
# INFO:tensorflow:global_step/sec: 56.3091
# INFO:tensorflow:loss = 2.4010117, step = 9001 (1.777 sec)
# INFO:tensorflow:global_step/sec: 59.704
# INFO:tensorflow:loss = 2.5793755, step = 9101 (1.674 sec)
# INFO:tensorflow:global_step/sec: 60.7941
# INFO:tensorflow:loss = 2.8437953, step = 9201 (1.645 sec)
# INFO:tensorflow:global_step/sec: 62.0665
# INFO:tensorflow:loss = 2.9688594, step = 9301 (1.611 sec)
# INFO:tensorflow:global_step/sec: 63.0065
# INFO:tensorflow:loss = 2.2545626, step = 9401 (1.587 sec)
# INFO:tensorflow:global_step/sec: 62.1095
# INFO:tensorflow:loss = 2.408917, step = 9501 (1.610 sec)
# INFO:tensorflow:global_step/sec: 61.3726
# INFO:tensorflow:loss = 2.4911294, step = 9601 (1.630 sec)
# INFO:tensorflow:global_step/sec: 58.6905
# INFO:tensorflow:loss = 2.5240436, step = 9701 (1.703 sec)
# INFO:tensorflow:global_step/sec: 61.4978
# INFO:tensorflow:loss = 2.843751, step = 9801 (1.626 sec)
# INFO:tensorflow:global_step/sec: 60.5963
# INFO:tensorflow:loss = 2.2166464, step = 9901 (1.650 sec)
# INFO:tensorflow:global_step/sec: 60.345
# INFO:tensorflow:loss = 2.8035088, step = 10001 (1.657 sec)
# INFO:tensorflow:global_step/sec: 57.5512
# INFO:tensorflow:loss = 2.8033626, step = 10101 (1.738 sec)
# INFO:tensorflow:global_step/sec: 56.4839
# INFO:tensorflow:loss = 2.71475, step = 10201 (1.770 sec)
# INFO:tensorflow:global_step/sec: 60.3456
# INFO:tensorflow:loss = 3.0908506, step = 10301 (1.658 sec)
# INFO:tensorflow:global_step/sec: 59.0197
# INFO:tensorflow:loss = 2.7013392, step = 10401 (1.694 sec)
# INFO:tensorflow:global_step/sec: 57.7218
# INFO:tensorflow:loss = 2.219921, step = 10501 (1.733 sec)
# INFO:tensorflow:global_step/sec: 61.1997
# INFO:tensorflow:loss = 2.453877, step = 10601 (1.634 sec)
# INFO:tensorflow:global_step/sec: 61.3897
# INFO:tensorflow:loss = 2.7984848, step = 10701 (1.629 sec)
# INFO:tensorflow:global_step/sec: 59.7221
# INFO:tensorflow:loss = 2.300597, step = 10801 (1.675 sec)
# INFO:tensorflow:global_step/sec: 59.5518
# INFO:tensorflow:loss = 1.4019109, step = 10901 (1.679 sec)
# INFO:tensorflow:global_step/sec: 60.203
# INFO:tensorflow:loss = 2.643403, step = 11001 (1.661 sec)
# INFO:tensorflow:global_step/sec: 55.5625
# INFO:tensorflow:loss = 2.5816398, step = 11101 (1.800 sec)
# INFO:tensorflow:global_step/sec: 48.3173
# INFO:tensorflow:loss = 3.1541417, step = 11201 (2.070 sec)
# INFO:tensorflow:global_step/sec: 57.0681
# INFO:tensorflow:loss = 2.130789, step = 11301 (1.753 sec)
# INFO:tensorflow:global_step/sec: 58.4042
# INFO:tensorflow:loss = 2.7683663, step = 11401 (1.712 sec)
# INFO:tensorflow:global_step/sec: 54.803
# INFO:tensorflow:loss = 2.9634562, step = 11501 (1.825 sec)
# INFO:tensorflow:global_step/sec: 56.7443
# INFO:tensorflow:loss = 2.957297, step = 11601 (1.762 sec)
# INFO:tensorflow:global_step/sec: 49.7321
# INFO:tensorflow:loss = 3.2407799, step = 11701 (2.011 sec)
# INFO:tensorflow:global_step/sec: 56.2296
# INFO:tensorflow:loss = 2.5925686, step = 11801 (1.778 sec)
# INFO:tensorflow:global_step/sec: 54.7492
# INFO:tensorflow:loss = 2.7172978, step = 11901 (1.827 sec)
# INFO:tensorflow:global_step/sec: 49.1884
# INFO:tensorflow:loss = 2.4748893, step = 12001 (2.033 sec)
# INFO:tensorflow:global_step/sec: 54.5508
# INFO:tensorflow:loss = 2.3940701, step = 12101 (1.833 sec)
# INFO:tensorflow:global_step/sec: 54.7944
# INFO:tensorflow:loss = 2.4787364, step = 12201 (1.825 sec)
# INFO:tensorflow:global_step/sec: 55.5178
# INFO:tensorflow:loss = 2.1868024, step = 12301 (1.801 sec)
# INFO:tensorflow:global_step/sec: 54.629
# INFO:tensorflow:loss = 2.9368687, step = 12401 (1.831 sec)
# INFO:tensorflow:global_step/sec: 48.8333
# INFO:tensorflow:loss = 3.032474, step = 12501 (2.048 sec)
# INFO:tensorflow:global_step/sec: 60.5801
# INFO:tensorflow:loss = 2.9476254, step = 12601 (1.651 sec)
# INFO:tensorflow:global_step/sec: 49.166
# INFO:tensorflow:loss = 2.4474258, step = 12701 (2.034 sec)
# INFO:tensorflow:global_step/sec: 49.7268
# INFO:tensorflow:loss = 2.3232772, step = 12801 (2.011 sec)
# INFO:tensorflow:global_step/sec: 50.295
# INFO:tensorflow:loss = 2.2197888, step = 12901 (1.988 sec)
# INFO:tensorflow:global_step/sec: 59.8545
# INFO:tensorflow:loss = 2.7507842, step = 13001 (1.671 sec)
# INFO:tensorflow:global_step/sec: 57.8298
# INFO:tensorflow:loss = 1.9140571, step = 13101 (1.729 sec)
# INFO:tensorflow:global_step/sec: 56.8995
# INFO:tensorflow:loss = 2.0373385, step = 13201 (1.758 sec)
# INFO:tensorflow:global_step/sec: 59.7825
# INFO:tensorflow:loss = 2.9105241, step = 13301 (1.673 sec)
# INFO:tensorflow:global_step/sec: 52.6664
# INFO:tensorflow:loss = 2.6904194, step = 13401 (1.899 sec)
# INFO:tensorflow:global_step/sec: 59.6336
# INFO:tensorflow:loss = 2.5466733, step = 13501 (1.677 sec)
# INFO:tensorflow:global_step/sec: 60.9458
# INFO:tensorflow:loss = 2.2948241, step = 13601 (1.641 sec)
# INFO:tensorflow:global_step/sec: 61.9219
# INFO:tensorflow:loss = 2.6200333, step = 13701 (1.615 sec)
# INFO:tensorflow:global_step/sec: 58.9007
# INFO:tensorflow:loss = 1.574907, step = 13801 (1.698 sec)
# INFO:tensorflow:global_step/sec: 59.54
# INFO:tensorflow:loss = 2.7304647, step = 13901 (1.680 sec)
# INFO:tensorflow:global_step/sec: 52.8543
# INFO:tensorflow:loss = 2.3867354, step = 14001 (1.892 sec)
# INFO:tensorflow:global_step/sec: 61.7624
# INFO:tensorflow:loss = 2.4949415, step = 14101 (1.619 sec)
# INFO:tensorflow:global_step/sec: 61.4672
# INFO:tensorflow:loss = 2.1402826, step = 14201 (1.627 sec)
# INFO:tensorflow:global_step/sec: 61.9617
# INFO:tensorflow:loss = 2.2060134, step = 14301 (1.614 sec)
# INFO:tensorflow:global_step/sec: 62.9091
# INFO:tensorflow:loss = 2.4232354, step = 14401 (1.590 sec)
# INFO:tensorflow:global_step/sec: 62.2116
# INFO:tensorflow:loss = 2.389417, step = 14501 (1.607 sec)
# INFO:tensorflow:global_step/sec: 62.4608
# INFO:tensorflow:loss = 2.1437578, step = 14601 (1.601 sec)
# INFO:tensorflow:global_step/sec: 62.7608
# INFO:tensorflow:loss = 2.0714853, step = 14701 (1.593 sec)
# INFO:tensorflow:global_step/sec: 62.5764
# INFO:tensorflow:loss = 2.6247191, step = 14801 (1.598 sec)
# INFO:tensorflow:global_step/sec: 59.8133
# INFO:tensorflow:loss = 2.4396303, step = 14901 (1.672 sec)
# INFO:tensorflow:global_step/sec: 62.4134
# INFO:tensorflow:loss = 3.1575444, step = 15001 (1.602 sec)
# INFO:tensorflow:global_step/sec: 61.9468
# INFO:tensorflow:loss = 2.3558881, step = 15101 (1.614 sec)
# INFO:tensorflow:global_step/sec: 61.7407
# INFO:tensorflow:loss = 2.6169724, step = 15201 (1.620 sec)
# INFO:tensorflow:global_step/sec: 63.1076
# INFO:tensorflow:loss = 2.1562967, step = 15301 (1.584 sec)
# INFO:tensorflow:global_step/sec: 63.0215
# INFO:tensorflow:loss = 2.4318907, step = 15401 (1.587 sec)
# INFO:tensorflow:global_step/sec: 62.8573
# INFO:tensorflow:loss = 2.5200803, step = 15501 (1.591 sec)
# INFO:tensorflow:global_step/sec: 62.8942
# INFO:tensorflow:loss = 2.8534403, step = 15601 (1.590 sec)
# INFO:tensorflow:global_step/sec: 62.4797
# INFO:tensorflow:loss = 1.994675, step = 15701 (1.601 sec)
# INFO:tensorflow:Saving checkpoints for 15790 into /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpy7np20if/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.2598333.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /var/folders/sx/fv0r97j96fz8njp14dt5g7940000gn/T/tmpy7np20if/model.ckpt-15790
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# Nearest to [six]: pearce, ranked, departments, financiers, transition,
# Nearest to [gold]: ounce, ounces, platinum, silver, bullion,
# Nearest to [japan]: protect, tobacco, imported, equipped, laundering,
# Nearest to [college]: basketball, football, graduates, contemporary, yale,
