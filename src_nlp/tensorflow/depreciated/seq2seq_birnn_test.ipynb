# %%
from seq2seq_birnn import Seq2Seq
import sys
if int(sys.version[0]) == 2:
    from io import open


def read_data(path):
    with open(path, 'r', encoding='utf-8') as f:
        return f.read()
# end function read_data


def build_map(data):
    specials = ['<GO>',  '<EOS>', '<PAD>', '<UNK>']
    chars = list(set([char for line in data.split('\n') for char in line]))
    idx2char = {idx: char for idx, char in enumerate(specials + chars)}
    char2idx = {char: idx for idx, char in idx2char.items()}
    return idx2char, char2idx
# end function build_map


def preprocess_data():
    X_data = read_data('temp/letters_source.txt')
    Y_data = read_data('temp/letters_target.txt')

    X_idx2char, X_char2idx = build_map(X_data)
    Y_idx2char, Y_char2idx = build_map(Y_data)

    x_unk = X_char2idx['<UNK>']
    y_unk = Y_char2idx['<UNK>']
    y_eos = Y_char2idx['<EOS>']

    X_indices = [[X_char2idx.get(char, x_unk) for char in line] for line in X_data.split('\n')]
    Y_indices = [[Y_char2idx.get(char, y_unk) for char in line] + [y_eos] for line in Y_data.split('\n')]

    return X_indices, Y_indices, X_char2idx, Y_char2idx, X_idx2char, Y_idx2char
# end function preprocess_data


def main():
    BATCH_SIZE = 128
    X_indices, Y_indices, X_char2idx, Y_char2idx, X_idx2char, Y_idx2char = preprocess_data()
    X_train = X_indices[BATCH_SIZE:]
    Y_train = Y_indices[BATCH_SIZE:]
    X_test = X_indices[:BATCH_SIZE]
    Y_test = Y_indices[:BATCH_SIZE]

    model = Seq2Seq(
        rnn_size = 50,
        n_layers = 2,
        X_word2idx = X_char2idx,
        encoder_embedding_dim = 15,
        Y_word2idx = Y_char2idx,
        decoder_embedding_dim = 15,
    )
    model.fit(X_train, Y_train, val_data=(X_test, Y_test), batch_size=BATCH_SIZE)
    model.infer('common', X_idx2char, Y_idx2char)
    model.infer('apple', X_idx2char, Y_idx2char)
    model.infer('zhedong', X_idx2char, Y_idx2char)
# end function main


if __name__ == '__main__':
    main()
# Out:
# Epoch 1/60 | Batch 0/77 | train_loss: 3.405 | test_loss: 3.398
# Epoch 1/60 | Batch 50/77 | train_loss: 2.829 | test_loss: 2.785
# Epoch 2/60 | Batch 0/77 | train_loss: 2.329 | test_loss: 2.323
# Epoch 2/60 | Batch 50/77 | train_loss: 1.781 | test_loss: 1.794
# Epoch 3/60 | Batch 0/77 | train_loss: 1.601 | test_loss: 1.613
# Epoch 3/60 | Batch 50/77 | train_loss: 1.341 | test_loss: 1.338
# Epoch 4/60 | Batch 0/77 | train_loss: 1.205 | test_loss: 1.226
# Epoch 4/60 | Batch 50/77 | train_loss: 1.059 | test_loss: 1.054
# Epoch 5/60 | Batch 0/77 | train_loss: 0.943 | test_loss: 0.975
# Epoch 5/60 | Batch 50/77 | train_loss: 0.845 | test_loss: 0.844
# Epoch 6/60 | Batch 0/77 | train_loss: 0.743 | test_loss: 0.779
# Epoch 6/60 | Batch 50/77 | train_loss: 0.682 | test_loss: 0.675
# Epoch 7/60 | Batch 0/77 | train_loss: 0.586 | test_loss: 0.625
# Epoch 7/60 | Batch 50/77 | train_loss: 0.559 | test_loss: 0.539
# Epoch 8/60 | Batch 0/77 | train_loss: 0.471 | test_loss: 0.502
# Epoch 8/60 | Batch 50/77 | train_loss: 0.457 | test_loss: 0.438
# Epoch 9/60 | Batch 0/77 | train_loss: 0.382 | test_loss: 0.403
# Epoch 9/60 | Batch 50/77 | train_loss: 0.377 | test_loss: 0.360
# Epoch 10/60 | Batch 0/77 | train_loss: 0.310 | test_loss: 0.327
# Epoch 10/60 | Batch 50/77 | train_loss: 0.310 | test_loss: 0.298
# Epoch 31/60 | Batch 50/77 | train_loss: 0.021 | test_loss: 0.022
# Epoch 32/60 | Batch 0/77 | train_loss: 0.018 | test_loss: 0.024
# Epoch 32/60 | Batch 50/77 | train_loss: 0.019 | test_loss: 0.021
# Epoch 33/60 | Batch 0/77 | train_loss: 0.017 | test_loss: 0.023
# Epoch 33/60 | Batch 50/77 | train_loss: 0.018 | test_loss: 0.020
# Epoch 34/60 | Batch 0/77 | train_loss: 0.015 | test_loss: 0.021
# Epoch 34/60 | Batch 50/77 | train_loss: 0.016 | test_loss: 0.019
# Epoch 35/60 | Batch 0/77 | train_loss: 0.014 | test_loss: 0.020
# Epoch 35/60 | Batch 50/77 | train_loss: 0.015 | test_loss: 0.018
# Epoch 36/60 | Batch 0/77 | train_loss: 0.013 | test_loss: 0.019
# Epoch 36/60 | Batch 50/77 | train_loss: 0.014 | test_loss: 0.017
# Epoch 37/60 | Batch 0/77 | train_loss: 0.012 | test_loss: 0.018
# Epoch 37/60 | Batch 50/77 | train_loss: 0.013 | test_loss: 0.016
# Epoch 38/60 | Batch 0/77 | train_loss: 0.011 | test_loss: 0.017
# Epoch 38/60 | Batch 50/77 | train_loss: 0.012 | test_loss: 0.016
# Epoch 39/60 | Batch 0/77 | train_loss: 0.011 | test_loss: 0.016
# Epoch 39/60 | Batch 50/77 | train_loss: 0.011 | test_loss: 0.015
# Epoch 40/60 | Batch 0/77 | train_loss: 0.010 | test_loss: 0.015
# Epoch 40/60 | Batch 50/77 | train_loss: 0.011 | test_loss: 0.015
# Epoch 41/60 | Batch 0/77 | train_loss: 0.009 | test_loss: 0.014
# Epoch 41/60 | Batch 50/77 | train_loss: 0.010 | test_loss: 0.014
# Epoch 42/60 | Batch 0/77 | train_loss: 0.009 | test_loss: 0.013
# Epoch 42/60 | Batch 50/77 | train_loss: 0.009 | test_loss: 0.013
# Epoch 43/60 | Batch 0/77 | train_loss: 0.008 | test_loss: 0.013
# Epoch 43/60 | Batch 50/77 | train_loss: 0.009 | test_loss: 0.013
# Epoch 44/60 | Batch 0/77 | train_loss: 0.008 | test_loss: 0.013
# Epoch 44/60 | Batch 50/77 | train_loss: 0.008 | test_loss: 0.012
# Epoch 45/60 | Batch 0/77 | train_loss: 0.007 | test_loss: 0.012
# Epoch 45/60 | Batch 50/77 | train_loss: 0.008 | test_loss: 0.012
# Epoch 46/60 | Batch 0/77 | train_loss: 0.007 | test_loss: 0.012
# Epoch 46/60 | Batch 50/77 | train_loss: 0.007 | test_loss: 0.011
# Epoch 47/60 | Batch 0/77 | train_loss: 0.006 | test_loss: 0.012
# Epoch 47/60 | Batch 50/77 | train_loss: 0.007 | test_loss: 0.011
# Epoch 48/60 | Batch 0/77 | train_loss: 0.006 | test_loss: 0.012
# Epoch 48/60 | Batch 50/77 | train_loss: 0.006 | test_loss: 0.010
# Epoch 49/60 | Batch 0/77 | train_loss: 0.006 | test_loss: 0.011
# Epoch 49/60 | Batch 50/77 | train_loss: 0.006 | test_loss: 0.010
# Epoch 50/60 | Batch 0/77 | train_loss: 0.005 | test_loss: 0.011
# Epoch 50/60 | Batch 50/77 | train_loss: 0.005 | test_loss: 0.010
# Epoch 51/60 | Batch 0/77 | train_loss: 0.005 | test_loss: 0.010
# Epoch 51/60 | Batch 50/77 | train_loss: 0.005 | test_loss: 0.009
# Epoch 52/60 | Batch 0/77 | train_loss: 0.005 | test_loss: 0.010
# Epoch 52/60 | Batch 50/77 | train_loss: 0.005 | test_loss: 0.009
# Epoch 53/60 | Batch 0/77 | train_loss: 0.004 | test_loss: 0.009
# Epoch 53/60 | Batch 50/77 | train_loss: 0.004 | test_loss: 0.008
# Epoch 54/60 | Batch 0/77 | train_loss: 0.004 | test_loss: 0.009
# Epoch 54/60 | Batch 50/77 | train_loss: 0.004 | test_loss: 0.008
# Epoch 55/60 | Batch 0/77 | train_loss: 0.004 | test_loss: 0.008
# Epoch 55/60 | Batch 50/77 | train_loss: 0.004 | test_loss: 0.008
# Epoch 56/60 | Batch 0/77 | train_loss: 0.004 | test_loss: 0.008
# Epoch 56/60 | Batch 50/77 | train_loss: 0.004 | test_loss: 0.007
# Epoch 57/60 | Batch 0/77 | train_loss: 0.003 | test_loss: 0.008
# Epoch 57/60 | Batch 50/77 | train_loss: 0.003 | test_loss: 0.007
# Epoch 58/60 | Batch 0/77 | train_loss: 0.003 | test_loss: 0.008
# Epoch 58/60 | Batch 50/77 | train_loss: 0.003 | test_loss: 0.007
# Epoch 59/60 | Batch 0/77 | train_loss: 0.003 | test_loss: 0.007
# Epoch 59/60 | Batch 50/77 | train_loss: 0.003 | test_loss: 0.007
# Epoch 60/60 | Batch 0/77 | train_loss: 0.003 | test_loss: 0.007
# Epoch 60/60 | Batch 50/77 | train_loss: 0.003 | test_loss: 0.006
# IN: c o m m o n
# OUT: c m m n o o <EOS>
#
# IN: a p p l e
# OUT: a e l p p <EOS>
#
# IN: z h e d o n g
# OUT: d e g h n o z <EOS>
